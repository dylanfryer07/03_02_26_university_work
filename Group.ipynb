# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Forward_Feast_Survey.csv') 
df.head(10)
# Out:
#    Survey ID Date of Survey    Age          Education Level Gender  Region  \
# 0        715        1 March  18-24               University   Male  London
# 1          0        1 March  18-24                  Masters   Male  London
# 2         98        1 March  18-24                  A-Level   Male  London
# 3        908        1 March  18-24                  A-Level   Male  London
# 4        415        1 March  18-24                  A-Level   Male  London
# 5        222        1 March  18-24               University   Male  London
# 6        172        1 March  18-24               University   Male  London
# 7         81        1 March  18-24                     GCSE   Male  London
# 8         75        1 March  18-24                  Masters   Male  London
# 9        274        1 March  18-24  No formal qualification   Male  London
#
#   Urban 1. Are you happy with the frequency with which you cook food at home  \
# 0  City                               I wish I'd cook more
# ...

# %%
df.columns
# Out:
# Index(['Survey ID', 'Date of Survey', 'Age', 'Education Level', 'Gender',
#        'Region', 'Urban',
#        '1. Are you happy with the frequency with which you cook food at home',
#        '1a. What is the primary reason you do not cook more frequently at home?',
#        '1b. What is the primary reason you'd want to cook more often at home',
#        '2. What would be key for an AI-based nutritional assistant to offer?',
#        '3. Which feature would be most important to you?',
#        '4. Do you currently use any meal planning, recipe app, or meal tracker',
#        '4a1. Would you be open to the idea of an AI-assistant that helps you eat better?',
#        '4b1. And are you satisfied with what you have?', '4b2. Why is that?',
#        '5. Would you consider paying £30 a year for this nutritional app?',
#        '5a1. Would you consider paying £10?',
#        '5a2. Would you prefer spending £1 a month or have to put up with ads?',
# ...

# %%
missing_data = (df.isna().sum() / len(df)) * 100

# 4b1. And are you satisfied with what you have?  column has 84 percent of values missing

# %%
df['4a1. Would you be open to the idea of an AI-assistant that helps you eat better?'].isnull().sum()
# Out:
# np.int64(51)

# %%
education_level = df['Education Level'].value_counts()
plt.bar(education_level.index, education_level.values)
plt.xlabel('Education Level')
plt.ylabel('Number of Respondents')
plt.title('Distribution of Education Levels among Survey Respondents')
plt.xticks(rotation=45)
plt.show()

# %%
gender = df['Gender'].value_counts()
plt.bar(gender.index, gender.values)
plt.xlabel('Gender')
plt.ylabel('Number of Respondents')
plt.title('Distribution of Gender among Survey Respondents')
plt.xticks(rotation=45)
plt.show()

# %%
missing_data
# Out:
# Survey ID                                                                                                                                        0.000000
# Date of Survey                                                                                                                                   0.000000
# Age                                                                                                                                              0.000000
# Education Level                                                                                                                                  0.000000
# Gender                                                                                                                                           0.000000
# Region                                                                                                                                           0.000000
# ...

# %%
# Visualizing missing data. 

plt.bar(missing_data.index, missing_data.values)
plt.xlabel('Columns')
plt.ylabel('Percentage of Missing Values')
plt.title('Percentage of Missing Values in Each Column')
plt.xticks(rotation=90)
plt.show()

# %%
import plotly.express as px
import pandas as pd
df = pd.read_csv("Forward_Feast_Survey.csv")
def visualise_age(df):
    fig_age = px.histogram(df, x="Age", nbins=20, title="Age Distribution of Survey Respondents")
    fig_age.show()
def visualise_education(df):
    fig_education = px.histogram(df, x="Education Level", title="Education Level Distribution")
    fig_education.show()
def visualise_region(df):
    fig_region = px.histogram(df, x="Region", title="Geographical Distribution of Respondents")
    fig_region.show()
def visualise_gender(df):
    fig_gender = px.histogram(df, x="Gender", title="Gender Distribution of Respondents")
    fig_gender.show()

visualise_age(df)
visualise_education(df)
visualise_region(df)
visualise_gender(df)
